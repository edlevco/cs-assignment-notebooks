# %% [markdown]
# <a href="https://colab.research.google.com/github/edlevco/cs-assignment-notebooks/blob/main/Eddie's_Assignement_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CISC 121 – Assignment-1
#
# ## 🔗 Problem
# Fizz Buzz – https://leetcode.com/problems/fizz-buzz/
#
# Palindrome Number – https://leetcode.com/problems/palindrome-number/
#
# Reverse Integer – https://leetcode.com/problems/reverse-integer/
#
# Two Sum – https://leetcode.com/problems/two-sum/
#
# Valid Palindrome – https://leetcode.com/problems/valid-palindrome/

# %% [markdown]
# #  Problem 1 | FIZZBUZZ

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
#Fizz Buzz

#First, I will create an empty array called answer
#Then, I will loop through the range of 1 to n + 1 and set that value to i
#ChatGPT Query: How many times will the loop 1 to n run
#Answer: It will have n iterations
#if i is divisible by 3 and 5, append "FizzBuzz" to the answer array
#elif i is divisible by 3, append "Fizz"
#elif i is divisible by 5, append "Buzz"
#else append i (The number itself) (as a string)

#I viewed the top solutions for the FizzBuzz problem
#https://leetcode.com/problems/fizz-buzz/
#and they were the same as mine

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def fizzBuzz(n):
  answer = []
  for i in range(1, n+1):
      if i % 5 == 0 and i % 3 == 0:
          answer.append("FizzBuzz")
      elif i % 3 == 0:
          answer.append("Fizz")
      elif i % 5 == 0:
          answer.append("Buzz")
      else:
          answer.append(f"{i}")
  return answer

print(fizzBuzz(15))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %% [markdown]
# :Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![Screenshot 2025-09-19 at 2.36.14 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-19 at 2.36.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-19 at 2.36.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# I did not improve anything because my method was the most optimal

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used chatGPT to ask how many times in range from 1 to n+1 itterates for the FizzBuzz. It told me n times, which is perfect because I needed n strings in my answer array
#
# 2.  I used ChatGPT to guide my how to add a screenshot on colabs. It told me to download it in the file, but i just added it in the text box
#
# 3. I used leetcode to code FizzBuzz and checked with the solutions to make sure my method had the quickest run time
#
# 4. Everything else I contributed myself

# %% [markdown]
# #  Problem 2 | PALINDROME
#
# ```
# # This is formatted as code
# ```

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
#Palidrome Number

#If the input has a length of 1, return true because it will be a palidrome number
# I will do a loop from 0 to len(x) // 2 (floor)
# If the number is even like 6, it needs 3 checks
# If the number is odd like 7 it still needs 3 checks because the middle number doesnt matter
# in the loop it will check if the first index is equal to the last
# It will repeat this from second and second last, inwards till the middle
# If they are not equal at any point the code will return false
# If the code never returns false, it will return true at the end, meaning it is a palidrom number

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def palidrome(n):
    return str(n) == str(n)[::-1]


print(palidrome(100001))
# Out:
# True

# %% [markdown]
# :Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![Screenshot 2025-09-20 at 2.01.34 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 2.02.53 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 2.02.19 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# 1.
# I improved my draft by changing the input to a string
# This helped the code recognize the negative in the front when I was indexing it
# When there was a negative, it would compare the symbol to a number
# Returning false


# 2.
# My draft method worked, but it only beat 50% of people's run times
# I looked at LeetCodes most optimal run time
# https://leetcode.com/problems/palindrome-number/
# And they solved the problem in one line by comparing the string of the int
# To the string of the reversed int

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used leetCode to debug. It told me that it can't skip by 0. I realized that I accidentally put [::0] instead of [::-1] to reverse my string
#
# 2.  I did not use ChatGPT or any other AI to solve this problem
#
# 3. I used LeetCode to learn what the lowest runtime solution was and I editted mine to be better
#
# 4. Everything else I contributed myself

# %% [markdown]
# #  Problem 3 | REVERSE INTEGER

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
#Reversed Integer

#Because I learned how to reverse an integer in the Palindrome number
# I can do the same for this one with one line of code
# Returning the string of the integer with indexing of -1 steps (reverse)

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def reversed_int(x):
  if x < 0:
    num = int(str(x*-1)[::-1]) * -1
    if num < -2**31:
      return 0
    return num
  num = int(str(x)[::-1])
  if num > 2**31 - 1:
    return 0
  return num

print(reversed_int(200))
# Out:
# 2

# %% [markdown]
# :Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![Screenshot 2025-09-20 at 2.22.32 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 2.22.39 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 2.22.45 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# 1.
# In my draft, I just revered the string, then changed it back into an integer
# I got an error because it wasnt a propper int if the negative sign was at the end
# If the number was less than 0, I changed it to positive, then reversed it, then back to negative
# I did this by multiplying the negative by * -1 then back to negative with * -1

# 2.
# I saw that there were restrictions on the max and min
# I checked if it was negative and less than the min, I returned 0
# if it was positive and more than the max I returned 0
# Otherwise, I returned the reversed number
# These restrictions, I found in leetcode when i tried to submit my code

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I did not use any other AI or other peoples code for this problem
#
# 2. I got some errors from leetcode, and I used that to fix my code

# %% [markdown]
# #  Problem 4 | 2 Sum

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
# 2 Sum

#I will solve this by looping through the array with 2 index
# so I will need to loops to each store 1 index
# the second loop will starts 1 ahead of the first loop so the same solution is
# not seen more that one time
# if the numbers at both indexs add up to the target
# The code will return the an array of the first and second index

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def two_sum(nums, target):
  seen = {}
  for i, num in enumerate(nums):
    difference = target-num
    if difference in seen:
      return [seen[difference], i]
    seen[num] = i

print(two_sum([2,7,11,15], 9))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %% [markdown]
# :Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![Screenshot 2025-09-20 at 3.09.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 3.10.02 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 3.10.08 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# 1.
# I used a hashmap to store the difference
# The hashmap / dictionary made it quicker because it only required one loop of all
# the numbers

# 2.
# I used one loop instead of two
# This made the run time significantly faster because it only had to go through it
# once rather than once squared (O(n^2))
# I was able to do this because of the hashmap and storing the difference

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used Leetcode to look at the most optimal solution. They used one loop and a dictionary to solve the problem
#
# 2.  I used ChatGPT to explain why a hashmap was better than an array, and to explain how the Leetcode worked, so i could understand it myself
#
# 3. I did not use any AI to fix bugs or help with errors in my code

# %% [markdown]
# #  Problem 5 | Palindrome

# %% [markdown]
# ## 1. Understanding & Breakdown
#
# _Understand the problem, inputs/outputs, constraints, and  write down your plan or steps to solve the problem or draw the flowchart using digital or real pen-paper. Insert the image._
#
# **AI Level 1** is allowed to understand the concept, but you need to sketch the problem down by yourself.
#
# **Your effort is more important than the accuracy for this section**

# %% [markdown]
# ## 2. Peer Review & Draft Code
#
# **Review Guidance:**
# Visit the **"Solutions"** tab on LeetCode for the selected problem and review at least one top-rated solution. You may also search for relevant discussions or Q&A threads on **Stack Overflow** or other forums to understand how others approached the problem.
#
# Then, write your own version based on what you understood. The goal is not to copy but to apply what you learned. Always include links to the resources you reviewed.
#
# ---
#
# ### **Example Answer (for "Palindrome Number"):**
#
# I reviewed the top solution under the LeetCode “Solutions” tab and one post on Stack Overflow:
# https://stackoverflow.com/questions/17129222/how-to-check-if-a-number-is-palindrome-in-python
#
# I learned that I can reverse the integer using a loop with modulo and division instead of converting it to a string. Using this idea, I tried writing a function that reverses the number and compares it to the original.

# %%
#Palindrome

#Take a string, remove all the non-alphanumeric characters, change uppercase into lower
#If it reads forward and backwards the same it is a palindrome

# ChatGPT said that .isalnum() with a char infront, returns true if it is a alphanumeric
# character, and false if not

#I will use this in my code to remove all the non-alphanumeric characters
#Then I will check if the reversed string is equal to the string

# %% [markdown]
# ## 3. Final Correct Code
#
# _This version must pass all required test cases and handle edge cases correctly._
#
# At this stage, you may:
# - Use reviewed solutions or programming AI tools (e.g., ChatGPT, GitHub Copilot) to refine and fix errors.
# - Refactor your draft to ensure accuracy and completeness.
#
#  **AI Level 4 is allowed**, but you **must include a disclaimer** that clearly states what tools you used, how you used them, and for which part of the code.

# %%
def isPalindrome(s):

  s = "".join(char for char in s.lower() if char.isalnum())

  return s == s[::-1]

print(isPalindrome("racecar"))
# Out:
# True

# %% [markdown]
# :Add the screenshot of output for all the test cases from your working solutions.

# %% [markdown]
# ![Screenshot 2025-09-20 at 3.53.46 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 3.53.51 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-20 at 3.53.57 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Review & Fixes
# _What did you improve from your draft? 2 fixes with your comments._

# %%
# 1.
#Instead of making a loop that went through the string and remove the non-alphanumerical characters
#I used general comprehension to make a new string that did it
# This way is much faster and more efficient

# For my general comprehension I had changed the character to lower for every character
# to make a my code faster, I changed the string to lower initially, so it only ran it once
#

# %% [markdown]
# ## 5. Reflection on Your Contribution
# _Where did AI or Other's code helped or fail to help? What specific logic or debugging did you contribute yourself?_
#
# ## Example
# 1. I used chatGPT to ask how to identify non-alphanumerical characters. It told me to use
# Char.isalnum() which returned true or false
#
# 2.  I used ChatGPT to help remind me how to use comprehension for a new string.
#
# 3. I used leetcode to check the best run times, but they were far too advanced.
#
# 4. Everything else I contributed myself

# %% [markdown]
# #  Repeat this template for Problems 2–5
# You may copy-paste the above section 4 more times or duplicate cells in your notebook environment.
#
# Remember:
# Proper attribution
# No copy-pasting from AI or others

# %% [markdown]
# 1. Your Name: Eddie Levcovich
# 2. Section: CISC 121 001
# 3. ID: 20522692
# 4. Github Link of this notebook: None
# 5. Chat/ (Saved Chat in a shared Document link)

# %% [markdown]
# # **The most important part of writing code is not the code itself, but the thinking that leads to it. Thank You**
